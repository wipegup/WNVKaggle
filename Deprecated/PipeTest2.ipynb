# %%
import shapefile
from scipy.spatial import cKDTree
import numpy as np
import pandas as pd
from os import listdir
from os.path import isfile, join
from sklearn.decomposition import TruncatedSVD
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import FunctionTransformer
from sklearn.linear_model import LinearRegression

# %%
train = pd.read_csv('./input/train.csv')
test = pd.read_csv('./input/test.csv', index_col= 0)

# %%
def agg_on_species(train, test):
    
    noAgg = [c for c in train.columns if c not in ['NumMosquitos','WnvPresent']]

    agg = train.groupby(noAgg)['NumMosquitos', 'WnvPresent'].sum()

    for i, c in enumerate(noAgg):
        agg[c] = agg.index.map(lambda x:x[i])

    agg.index = range(0,len(agg))
    agg['WnvPresent'] = (agg['WnvPresent'].map(lambda x:x>0)).astype(int)
    return agg, test

# %%
def InitPrepross(train, test):

    def location_add(df):
        df['Location'] = [(df.loc[idx,'Longitude'], df.loc[idx, 'Latitude'])
                            for idx in df.index]
        return df

    def change_date(df):
        df['Date'] = pd.to_datetime(df['Date'])

        return df

    def drop_unused(df):
        for col in ['Address','Block','Street',
              'AddressNumberAndStreet', 'AddressAccuracy',
                    ]:
            try:
                df = df.drop(col, axis = 'columns')
            except:
                print(col, 'not present')

        return df

    def species_dummies(df):
        species = ['CULEX PIPIENS', 'CULEX PIPIENS/RESTUANS',
                'CULEX RESTUANS', 'CULEX SALINARIUS',
                'CULEX TERRITANS', 'CULEX TARSALIS',
                 'CULEX ERRATICUS']
        for s in species:
            df[s] = (df['Species'] == s).astype(int)

        return df

    def transform(df):
        df = drop_unused(df)
        df = location_add(df)
        df = change_date(df)
        df = species_dummies(df)
        return df
        
    return transform(train), transform(test)

# %%
tup = InitPrepross(train,test)

# %%
df.head(2)
# Out:
#          Date                 Species  Trap  Latitude  Longitude  \
# 0  2007-05-29  CULEX PIPIENS/RESTUANS  T002  41.95469 -87.800991
# 1  2007-05-29          CULEX RESTUANS  T002  41.95469 -87.800991
#
#    NumMosquitos  WnvPresent                Location
# 0             1           0  (-87.800991, 41.95469)
# 1             1           0  (-87.800991, 41.95469)

# %%
tup = InitPrepross(train, test)

# %%
def LocationProcess(train, test):
    parkDir = './AddData/Parks/'
    waterDir = './AddData/Water/'

    def buildWaterFinder():
        water = [f for f in listdir(waterDir)
                if isfile(join(waterDir,f))
                if f.count('.csv') ==0]

        waterShape = waterDir + water[0].split('.')[0]
        waterSR = shapefile.Reader(waterShape).shapeRecords()

        waterFinder = {}
        for i, s in enumerate(waterSR):
            waterFinder[i] = cKDTree(s.shape.points)

        return waterFinder

    def buildParkDicts():
        parks = [f for f in listdir(parkDir)
                if isfile(join(parkDir,f))
                if f.count('.csv') ==0]
        parkShape = parkDir + parks[0].split('.')[0]
        parkSR = shapefile.Reader(parkShape).shapeRecords()

        parkFinder = {}
        parkSize = {}
        for s in parkSR:
            parkSize[s.record[4]] = s.record[19]
            parkFinder[s.record[4]] = cKDTree(s.shape.points)

        return parkFinder, parkSize

    def calculate_distances(loc, finder, size = None):
        Dist = {}
        for k in finder:
            Dist[k] = finder[k].query(loc, 1)[0]

        if size:
            toRet = {}
            for k in Dist:
                Dist[k] = (Dist[k], size[k], size[k]/(Dist[k]**2))
        return Dist

    def dfFromDict(dct):
        toRet = pd.DataFrame(dct)
        toRet = toRet.transpose()
        toRet.index = [idx for idx in toRet.index]

        if type(toRet.iloc[0,0]) == tuple:
            for c in toRet:
                toRet['P ' + str(c) + ' A'] = [e[1] for e in toRet[c]]
                toRet['P ' + str(c) + ' E'] = [e[2] for e in toRet[c]]
                toRet['P ' + str(c)] = [e[0] for e in toRet[c]]
                toRet = toRet.drop(c, axis = 'columns')
        else:
            toRet.columns = ['W ' + str(c) for c in toRet.columns]

        return toRet

    def info(df, finder, size = None):
        uniqueLocs = df['Location'].unique()
        rows = {}
        for loc in uniqueLocs:
            rows[loc] = calculate_distances(loc, finder, size)

        return dfFromDict(rows)

    def transform(df):
        toRet = pd.concat( [info(df, waterFinder),
                    info(df, parkFinder, parkSize)],
                    axis = 'columns')

        return toRet

    parkFinder, parkSize = buildParkDicts()
    waterFinder = buildWaterFinder()

    # Returns DFs: index = locations
    return transform(train), transform(test)

# %%
tup2 = LocationProcess(tup[0], tup[1])

# %%
tup2[0].shape
# Out:
# (138, 2396)

# %%
len([c for c in tup2[1].columns if (c[0] != 'W') & (c[0] != 'P')])
# Out:
# 0

# %%
def SVD(train, test):

    def find_cols(df, tpe):
        mask = [c for c in df.columns if c[0] == tpe ]

        return df.loc[:,mask]

    def yeildFitTSVD(df):
        comps = 4

        TSVD = TruncatedSVD(n_components = comps)
        TSVD.fit(df)

        return TSVD

    def transformTSVD(df, TSVD):
        toRet = TSVD.transform(df)
        toRet = pd.DataFrame(toRet, index = df.index)
        #print(toRet)
        return toRet

    
    toRetTrain = []
    toRetTest = []
    for t in ['W', 'P']:
        sTrain = find_cols(train, t)
        sTest = find_cols(test,t)
        sTSVD = yeildFitTSVD(sTrain)

        toRetTrain.append(transformTSVD(sTrain, sTSVD))
        toRetTest.append(transformTSVD(sTest, sTSVD))

    toRetTrain = pd.concat(toRetTrain, axis = 'columns')
    toRetTest = pd.concat(toRetTest, axis = 'columns')

    return toRetTrain, toRetTest

# %%
tup2[0].loc[:,[c for c in tup2[0].columns if c[0] == 'W']]
# Out:
#                                                W 0       W 1       W 2  \
# (-87.930995, 41.957799)                   0.258189  0.273510  0.280411
# (-87.890615, 41.974689)                   0.231906  0.246757  0.252666
# (-87.862995, 41.992478000000006)          0.221358  0.235498  0.240353
# (-87.832763, 41.944869)                   0.167559  0.182201  0.187844
# (-87.824812, 41.974089)                   0.181188  0.194910  0.199303
# (-87.812827, 41.981964000000005)          0.179164  0.192306  0.196046
# (-87.81150600000001, 42.011601)           0.202275  0.214563  0.217380
# (-87.807277, 42.009876)                   0.198516  0.210690  0.213402
# (-87.805059, 41.973845000000004)          0.167966  0.181077  0.184810
# (-87.800991, 41.95469)                    0.150756  0.164328  0.168614
# (-87.800515, 41.916265)                   0.124604  0.139383  0.145327
# (-87.797894, 41.797616)                   0.107894  0.119970  0.129859
# (-87.797127, 41.990284)                   0.176562  0.188871  0.191764
# (-87.795585, 41.999128999999996)          0.183191  0.195179  0.197748
# (-87.79518, 41.921177)                    0.123381  0.137887  0.143425
# (-87.794896, 41.94016)                    0.136001  0.149853  0.154510
# (-87.787992, 41.970248)                   0.154851  0.167387  0.170566
# (-87.785288, 41.923738)                   0.117639  0.131761  0.136809
# (-87.562889, 41.766202)                   0.125892  0.129592  0.128799
# (-87.559308, 41.678618)                   0.195319  0.197108  0.197026
# (-87.55551, 41.733643)                    0.153552  0.156652  0.156022
# (-87.546587, 41.740641)                   0.154963  0.158389  0.157672
# (-87.54306700000001, 41.737052)           0.159984  0.163401  0.162687
# (-87.53869300000001, 41.659112)           0.222812  0.224953  0.224643
# (-87.536497, 41.702723999999996)          0.189252  0.192159  0.191582
# (-87.535198, 41.680946)                   0.206978  0.209570  0.209077
# (-87.531657, 41.717753)                   0.181577  0.184830  0.184161
# (-87.531635, 41.686398)                   0.204889  0.207628  0.207096
#
# [138 rows x 605 columns]

# %%
list(tup2[0].columns)
# Out:
# ['W 0',
#  'W 1',
#  'W 2',
#  'W 3',
#  'W 4',
#  'W 5',
#  'W 6',
#  'W 7',
#  'W 8',
#  'W 9',
#  'W 10',
#  'W 11',
#  'W 12',
#  'W 13',
#  'W 14',
#  'W 15',
#  'W 16',
#  'W 17',
#  'W 18',
#  'W 19',
#  'W 20',
#  'W 21',
#  'W 22',
#  'W 23',
#  'W 24',
#  'W 25',
#  'W 26',
#  'W 27',
#  'W 28',
#  'W 29',
#  'W 30',
#  'W 31',
#  'W 32',
#  'W 33',
#  'W 34',
#  'W 35',
#  'W 36',
#  'W 37',
#  'W 38',
#  'W 39',
#  'W 40',
#  'W 41',
#  'W 42',
#  'W 43',
#  'W 44',
#  'W 45',
#  'W 46',
#  'W 47',
#  'W 48',
#  'W 49',
#  'W 50',
#  'W 51',
#  'W 52',
#  'W 53',
#  'W 54',
#  'W 55',
#  'W 56',
#  'W 57',
#  'W 58',
#  'W 59',
#  'W 60',
#  'W 61',
#  'W 62',
#  'W 63',
#  'W 64',
#  'W 65',
#  'W 66',
#  'W 67',
#  'W 68',
#  'W 69',
#  'W 70',
#  'W 71',
#  'W 72',
#  'W 73',
#  'W 74',
#  'W 75',
#  'W 76',
#  'W 77',
#  'W 78',
#  'W 79',
#  'W 80',
#  'W 81',
#  'W 82',
#  'W 83',
#  'W 84',
#  'W 85',
#  'W 86',
#  'W 87',
#  'W 88',
#  'W 89',
#  'W 90',
#  'W 91',
#  'W 92',
#  'W 93',
#  'W 94',
#  'W 95',
#  'W 96',
#  'W 97',
#  'W 98',
#  'W 99',
#  'W 100',
#  'W 101',
#  'W 102',
#  'W 103',
#  'W 104',
#  'W 105',
#  'W 106',
#  'W 107',
#  'W 108',
#  'W 109',
#  'W 110',
#  'W 111',
#  'W 112',
#  'W 113',
#  'W 114',
#  'W 115',
#  'W 116',
#  'W 117',
#  'W 118',
#  'W 119',
#  'W 120',
#  'W 121',
#  'W 122',
#  'W 123',
#  'W 124',
#  'W 125',
#  'W 126',
#  'W 127',
#  'W 128',
#  'W 129',
#  'W 130',
#  'W 131',
#  'W 132',
#  'W 133',
#  'W 134',
#  'W 135',
#  'W 136',
#  'W 137',
#  'W 138',
#  'W 139',
#  'W 140',
#  'W 141',
#  'W 142',
#  'W 143',
#  'W 144',
#  'W 145',
#  'W 146',
#  'W 147',
#  'W 148',
#  'W 149',
#  'W 150',
#  'W 151',
#  'W 152',
#  'W 153',
#  'W 154',
#  'W 155',
#  'W 156',
#  'W 157',
#  'W 158',
#  'W 159',
#  'W 160',
#  'W 161',
#  'W 162',
#  'W 163',
#  'W 164',
#  'W 165',
#  'W 166',
#  'W 167',
#  'W 168',
#  'W 169',
#  'W 170',
#  'W 171',
#  'W 172',
#  'W 173',
#  'W 174',
#  'W 175',
#  'W 176',
#  'W 177',
#  'W 178',
#  'W 179',
#  'W 180',
#  'W 181',
#  'W 182',
#  'W 183',
#  'W 184',
#  'W 185',
#  'W 186',
#  'W 187',
#  'W 188',
#  'W 189',
#  'W 190',
#  'W 191',
#  'W 192',
#  'W 193',
#  'W 194',
#  'W 195',
#  'W 196',
#  'W 197',
#  'W 198',
#  'W 199',
#  'W 200',
#  'W 201',
#  'W 202',
#  'W 203',
#  'W 204',
#  'W 205',
#  'W 206',
#  'W 207',
#  'W 208',
#  'W 209',
#  'W 210',
#  'W 211',
#  'W 212',
#  'W 213',
#  'W 214',
#  'W 215',
#  'W 216',
#  'W 217',
#  'W 218',
#  'W 219',
#  'W 220',
#  'W 221',
#  'W 222',
#  'W 223',
#  'W 224',
#  'W 225',
#  'W 226',
#  'W 227',
#  'W 228',
#  'W 229',
#  'W 230',
#  'W 231',
#  'W 232',
#  'W 233',
#  'W 234',
#  'W 235',
#  'W 236',
#  'W 237',
#  'W 238',
#  'W 239',
#  'W 240',
#  'W 241',
#  'W 242',
#  'W 243',
#  'W 244',
#  'W 245',
#  'W 246',
#  'W 247',
#  'W 248',
#  'W 249',
#  'W 250',
#  'W 251',
#  'W 252',
#  'W 253',
#  'W 254',
#  'W 255',
#  'W 256',
#  'W 257',
#  'W 258',
#  'W 259',
#  'W 260',
#  'W 261',
#  'W 262',
#  'W 263',
#  'W 264',
#  'W 265',
#  'W 266',
#  'W 267',
#  'W 268',
#  'W 269',
#  'W 270',
#  'W 271',
#  'W 272',
#  'W 273',
#  'W 274',
#  'W 275',
#  'W 276',
#  'W 277',
#  'W 278',
#  'W 279',
#  'W 280',
#  'W 281',
#  'W 282',
#  'W 283',
#  'W 284',
#  'W 285',
#  'W 286',
#  'W 287',
#  'W 288',
#  'W 289',
#  'W 290',
#  'W 291',
#  'W 292',
#  'W 293',
#  'W 294',
#  'W 295',
#  'W 296',
#  'W 297',
#  'W 298',
#  'W 299',
#  'W 300',
#  'W 301',
#  'W 302',
#  'W 303',
#  'W 304',
#  'W 305',
#  'W 306',
#  'W 307',
#  'W 308',
#  'W 309',
#  'W 310',
#  'W 311',
#  'W 312',
#  'W 313',
#  'W 314',
#  'W 315',
#  'W 316',
#  'W 317',
#  'W 318',
#  'W 319',
#  'W 320',
#  'W 321',
#  'W 322',
#  'W 323',
#  'W 324',
#  'W 325',
#  'W 326',
#  'W 327',
#  'W 328',
#  'W 329',
#  'W 330',
#  'W 331',
#  'W 332',
#  'W 333',
#  'W 334',
#  'W 335',
#  'W 336',
#  'W 337',
#  'W 338',
#  'W 339',
#  'W 340',
#  'W 341',
#  'W 342',
#  'W 343',
#  'W 344',
#  'W 345',
#  'W 346',
#  'W 347',
#  'W 348',
#  'W 349',
#  'W 350',
#  'W 351',
#  'W 352',
#  'W 353',
#  'W 354',
#  'W 355',
#  'W 356',
#  'W 357',
#  'W 358',
#  'W 359',
#  'W 360',
#  'W 361',
#  'W 362',
#  'W 363',
#  'W 364',
#  'W 365',
#  'W 366',
#  'W 367',
#  'W 368',
#  'W 369',
#  'W 370',
#  'W 371',
#  'W 372',
#  'W 373',
#  'W 374',
#  'W 375',
#  'W 376',
#  'W 377',
#  'W 378',
#  'W 379',
#  'W 380',
#  'W 381',
#  'W 382',
#  'W 383',
#  'W 384',
#  'W 385',
#  'W 386',
#  'W 387',
#  'W 388',
#  'W 389',
#  'W 390',
#  'W 391',
#  'W 392',
#  'W 393',
#  'W 394',
#  'W 395',
#  'W 396',
#  'W 397',
#  'W 398',
#  'W 399',
#  'W 400',
#  'W 401',
#  'W 402',
#  'W 403',
#  'W 404',
#  'W 405',
#  'W 406',
#  'W 407',
#  'W 408',
#  'W 409',
#  'W 410',
#  'W 411',
#  'W 412',
#  'W 413',
#  'W 414',
#  'W 415',
#  'W 416',
#  'W 417',
#  'W 418',
#  'W 419',
#  'W 420',
#  'W 421',
#  'W 422',
#  'W 423',
#  'W 424',
#  'W 425',
#  'W 426',
#  'W 427',
#  'W 428',
#  'W 429',
#  'W 430',
#  'W 431',
#  'W 432',
#  'W 433',
#  'W 434',
#  'W 435',
#  'W 436',
#  'W 437',
#  'W 438',
#  'W 439',
#  'W 440',
#  'W 441',
#  'W 442',
#  'W 443',
#  'W 444',
#  'W 445',
#  'W 446',
#  'W 447',
#  'W 448',
#  'W 449',
#  'W 450',
#  'W 451',
#  'W 452',
#  'W 453',
#  'W 454',
#  'W 455',
#  'W 456',
#  'W 457',
#  'W 458',
#  'W 459',
#  'W 460',
#  'W 461',
#  'W 462',
#  'W 463',
#  'W 464',
#  'W 465',
#  'W 466',
#  'W 467',
#  'W 468',
#  'W 469',
#  'W 470',
#  'W 471',
#  'W 472',
#  'W 473',
#  'W 474',
#  'W 475',
#  'W 476',
#  'W 477',
#  'W 478',
#  'W 479',
#  'W 480',
#  'W 481',
#  'W 482',
#  'W 483',
#  'W 484',
#  'W 485',
#  'W 486',
#  'W 487',
#  'W 488',
#  'W 489',
#  'W 490',
#  'W 491',
#  'W 492',
#  'W 493',
#  'W 494',
#  'W 495',
#  'W 496',
#  'W 497',
#  'W 498',
#  'W 499',
#  'W 500',
#  'W 501',
#  'W 502',
#  'W 503',
#  'W 504',
#  'W 505',
#  'W 506',
#  'W 507',
#  'W 508',
#  'W 509',
#  'W 510',
#  'W 511',
#  'W 512',
#  'W 513',
#  'W 514',
#  'W 515',
#  'W 516',
#  'W 517',
#  'W 518',
#  'W 519',
#  'W 520',
#  'W 521',
#  'W 522',
#  'W 523',
#  'W 524',
#  'W 525',
#  'W 526',
#  'W 527',
#  'W 528',
#  'W 529',
#  'W 530',
#  'W 531',
#  'W 532',
#  'W 533',
#  'W 534',
#  'W 535',
#  'W 536',
#  'W 537',
#  'W 538',
#  'W 539',
#  'W 540',
#  'W 541',
#  'W 542',
#  'W 543',
#  'W 544',
#  'W 545',
#  'W 546',
#  'W 547',
#  'W 548',
#  'W 549',
#  'W 550',
#  'W 551',
#  'W 552',
#  'W 553',
#  'W 554',
#  'W 555',
#  'W 556',
#  'W 557',
#  'W 558',
#  'W 559',
#  'W 560',
#  'W 561',
#  'W 562',
#  'W 563',
#  'W 564',
#  'W 565',
#  'W 566',
#  'W 567',
#  'W 568',
#  'W 569',
#  'W 570',
#  'W 571',
#  'W 572',
#  'W 573',
#  'W 574',
#  'W 575',
#  'W 576',
#  'W 577',
#  'W 578',
#  'W 579',
#  'W 580',
#  'W 581',
#  'W 582',
#  'W 583',
#  'W 584',
#  'W 585',
#  'W 586',
#  'W 587',
#  'W 588',
#  'W 589',
#  'W 590',
#  'W 591',
#  'W 592',
#  'W 593',
#  'W 594',
#  'W 595',
#  'W 596',
#  'W 597',
#  'W 598',
#  'W 599',
#  'W 600',
#  'W 601',
#  'W 602',
#  'W 603',
#  'W 604',
#  'P ABBOTT (ROBERT) A',
#  'P ABBOTT (ROBERT) E',
#  'P ABBOTT (ROBERT)',
#  'P ADA (SAWYER GARRETT) A',
#  'P ADA (SAWYER GARRETT) E',
#  'P ADA (SAWYER GARRETT)',
#  'P ADAMS (GEORGE & ADELE) A',
#  'P ADAMS (GEORGE & ADELE) E',
#  'P ADAMS (GEORGE & ADELE)',
#  'P ADAMS (JOHN C.) A',
#  'P ADAMS (JOHN C.) E',
#  'P ADAMS (JOHN C.)',
#  'P ADDAMS (JANE) A',
#  'P ADDAMS (JANE) E',
#  'P ADDAMS (JANE)',
#  'P ADDAMS (JANE) MEML. A',
#  'P ADDAMS (JANE) MEML. E',
#  'P ADDAMS (JANE) MEML.',
#  'P AIELLO (JOHN) A',
#  'P AIELLO (JOHN) E',
#  'P AIELLO (JOHN)',
#  'P ALGONQUIN A',
#  'P ALGONQUIN E',
#  'P ALGONQUIN',
#  'P ALMOND A',
#  'P ALMOND E',
#  'P ALMOND',
#  'P ALTGELD (JOHN) A',
#  'P ALTGELD (JOHN) E',
#  'P ALTGELD (JOHN)',
#  'P AMUNDSEN (ROALD) A',
#  'P AMUNDSEN (ROALD) E',
#  'P AMUNDSEN (ROALD)',
#  'P ANDERSON (FRED) A',
#  'P ANDERSON (FRED) E',
#  'P ANDERSON (FRED)',
#  'P ANDERSON (LOUIS) A',
#  'P ANDERSON (LOUIS) E',
#  'P ANDERSON (LOUIS)',
#  'P ANDERSONVILLE A',
#  'P ANDERSONVILLE E',
#  'P ANDERSONVILLE',
#  'P ARCADE A',
#  'P ARCADE E',
#  'P ARCADE',
#  'P ARCHER (WILLIAM BEATTY) A',
#  'P ARCHER (WILLIAM BEATTY) E',
#  'P ARCHER (WILLIAM BEATTY)',
#  'P ARMOUR (PHILIP) SQUARE A',
#  'P ARMOUR (PHILIP) SQUARE E',
#  'P ARMOUR (PHILIP) SQUARE',
#  'P ARMSTRONG (LILLIAN HARDIN) A',
#  'P ARMSTRONG (LILLIAN HARDIN) E',
#  'P ARMSTRONG (LILLIAN HARDIN)',
#  'P ARRIGO (VICTOR) A',
#  'P ARRIGO (VICTOR) E',
#  'P ARRIGO (VICTOR)',
#  'P ASHE (ARTHUR) BEACH A',
#  'P ASHE (ARTHUR) BEACH E',
#  'P ASHE (ARTHUR) BEACH',
#  'P ASHMORE A',
#  'P ASHMORE E',
#  'P ASHMORE',
#  'P ASPEN A',
#  'P ASPEN E',
#  'P ASPEN',
#  'P ASTER A',
#  'P ASTER E',
#  'P ASTER',
#  'P ATHLETIC FIELD A',
#  'P ATHLETIC FIELD E',
#  'P ATHLETIC FIELD',
#  'P AUBURN A',
#  'P AUBURN E',
#  'P AUBURN',
#  'P AUGUSTA (CARPENTER) A',
#  'P AUGUSTA (CARPENTER) E',
#  'P AUGUSTA (CARPENTER)',
#  'P AUSTIN (HENRY) A',
#  'P AUSTIN (HENRY) E',
#  'P AUSTIN (HENRY)',
#  'P AUSTIN FOSTER A',
#  'P AUSTIN FOSTER E',
#  'P AUSTIN FOSTER',
#  'P AUSTIN TOWN HALL A',
#  'P AUSTIN TOWN HALL E',
#  'P AUSTIN TOWN HALL',
#  'P AVALON A',
#  'P AVALON E',
#  'P AVALON',
#  'P AVONDALE A',
#  'P AVONDALE E',
#  'P AVONDALE',
#  'P BACK OF THE YARDS A',
#  'P BACK OF THE YARDS E',
#  'P BACK OF THE YARDS',
#  'P BARAGA (FREDERICK) A',
#  'P BARAGA (FREDERICK) E',
#  'P BARAGA (FREDERICK)',
#  'P BARBERRY A',
#  'P BARBERRY E',
#  'P BARBERRY',
#  'P BARNARD (ERASTUS) A',
#  'P BARNARD (ERASTUS) E',
#  'P BARNARD (ERASTUS)',
#  'P BARRETT (JOHN) A',
#  'P BARRETT (JOHN) E',
#  'P BARRETT (JOHN)',
#  'P BARTELME (MARY) A',
#  'P BARTELME (MARY) E',
#  'P BARTELME (MARY)',
#  'P BATTLE OF FORT DEARBORN A',
#  'P BATTLE OF FORT DEARBORN E',
#  'P BATTLE OF FORT DEARBORN',
#  'P BAULER (MATHIAS) A',
#  'P BAULER (MATHIAS) E',
#  'P BAULER (MATHIAS)',
#  'P BEEHIVE A',
#  'P BEEHIVE E',
#  'P BEEHIVE',
#  'P BEILFUSS (ALBERT W.) A',
#  'P BEILFUSS (ALBERT W.) E',
#  'P BEILFUSS (ALBERT W.)',
#  'P BELL (GEORGE,JR.) A',
#  'P BELL (GEORGE,JR.) E',
#  'P BELL (GEORGE,JR.)',
#  'P BENIAC (JOHN "BEANS") GREENWAY A',
#  'P BENIAC (JOHN "BEANS") GREENWAY E',
#  'P BENIAC (JOHN "BEANS") GREENWAY',
#  'P BERGER (ALBERT) A',
#  'P BERGER (ALBERT) E',
#  'P BERGER (ALBERT)',
#  'P BESSEMER (HENRY) A',
#  'P BESSEMER (HENRY) E',
#  'P BESSEMER (HENRY)',
#  'P BEVERLY A',
#  'P BEVERLY E',
#  'P BEVERLY',
#  'P BICKERDIKE (GEORGE) SQUARE A',
#  'P BICKERDIKE (GEORGE) SQUARE E',
#  'P BICKERDIKE (GEORGE) SQUARE',
#  'P BIRCH A',
#  'P BIRCH E',
#  'P BIRCH',
#  'P BIXLER (RAY) A',
#  'P BIXLER (RAY) E',
#  'P BIXLER (RAY)',
#  'P BLACKHAWK A',
#  'P BLACKHAWK E',
#  'P BLACKHAWK',
#  'P BLACKWELDER (I.S., GERTRUDE) A',
#  'P BLACKWELDER (I.S., GERTRUDE) E',
#  'P BLACKWELDER (I.S., GERTRUDE)',
#  'P BLOCK A',
#  'P BLOCK E',
#  'P BLOCK',
#  'P BOGAN (WILLIAM) A',
#  'P BOGAN (WILLIAM) E',
#  'P BOGAN (WILLIAM)',
#  'P BOHN (HENRY) A',
#  'P BOHN (HENRY) E',
#  'P BOHN (HENRY)',
#  'P BOLER (LEO ROSCOE, SR.) A',
#  'P BOLER (LEO ROSCOE, SR.) E',
#  'P BOLER (LEO ROSCOE, SR.)',
#  'P BOSLEY (WILLIAM) A',
#  'P BOSLEY (WILLIAM) E',
#  'P BOSLEY (WILLIAM)',
#  'P BOSWELL (ARNITA YOUNG) A',
#  'P BOSWELL (ARNITA YOUNG) E',
#  'P BOSWELL (ARNITA YOUNG)',
#  'P BRADLEY (JOSEPHINE) A',
#  'P BRADLEY (JOSEPHINE) E',
#  'P BRADLEY (JOSEPHINE)',
#  'P BRAINERD A',
#  'P BRAINERD E',
#  'P BRAINERD',
#  'P BRANDS A',
#  'P BRANDS E',
#  'P BRANDS',
#  'P BRIGHTON A',
#  'P BRIGHTON E',
#  'P BRIGHTON',
#  'P BROADWAY ARMORY A',
#  'P BROADWAY ARMORY E',
#  'P BROADWAY ARMORY',
#  'P BROMANN (CHARLES) A',
#  'P BROMANN (CHARLES) E',
#  'P BROMANN (CHARLES)',
#  'P BRONCHO BILLY A',
#  'P BRONCHO BILLY E',
#  'P BRONCHO BILLY',
#  'P BROOKS (GWENDOLYN) A',
#  'P BROOKS (GWENDOLYN) E',
#  'P BROOKS (GWENDOLYN)',
#  'P BROOKS (OSCAR) A',
#  'P BROOKS (OSCAR) E',
#  'P BROOKS (OSCAR)',
#  'P BROWN (SIDNEY) MEML. A',
#  'P BROWN (SIDNEY) MEML. E',
#  'P BROWN (SIDNEY) MEML.',
#  'P BRYNFORD A',
#  'P BRYNFORD E',
#  'P BRYNFORD',
#  'P BUENA CIRCLE A',
#  'P BUENA CIRCLE E',
#  'P BUENA CIRCLE',
#  'P BUFFALO A',
#  'P BUFFALO E',
#  'P BUFFALO',
#  'P BURNHAM (DANIEL) A',
#  'P BURNHAM (DANIEL) E',
#  'P BURNHAM (DANIEL)',
#  'P BURNSIDE (AMBROSE) A',
#  'P BURNSIDE (AMBROSE) E',
#  'P BURNSIDE (AMBROSE)',
#  'P BUTTERCUP A',
#  'P BUTTERCUP E',
#  'P BUTTERCUP',
#  'P BUTTERNUT A',
#  'P BUTTERNUT E',
#  'P BUTTERNUT',
#  'P CALIFORNIA A',
#  'P CALIFORNIA E',
#  'P CALIFORNIA',
#  'P CALUMET A',
#  'P CALUMET E',
#  'P CALUMET',
#  'P CANAL ORIGINS A',
#  'P CANAL ORIGINS E',
#  'P CANAL ORIGINS',
#  'P CANALPORT RIVERWALK A',
#  'P CANALPORT RIVERWALK E',
#  'P CANALPORT RIVERWALK',
#  'P CARMEN A',
#  'P CARMEN E',
#  'P CARMEN',
#  'P CARPENTER (PHILO) A',
#  'P CARPENTER (PHILO) E',
#  'P CARPENTER (PHILO)',
#  'P CARVER (GEORGE WASHINGTON) A',
#  'P CARVER (GEORGE WASHINGTON) E',
#  'P CARVER (GEORGE WASHINGTON)',
#  'P CATALPA A',
#  'P CATALPA E',
#  'P CATALPA',
#  'P CEDAR A',
#  'P CEDAR E',
#  'P CEDAR',
#  'P CENTENNIAL A',
#  'P CENTENNIAL E',
#  'P CENTENNIAL',
#  'P CENTRAL A',
#  'P CENTRAL E',
#  'P CENTRAL',
#  'P CHALLENGER A',
#  'P CHALLENGER E',
#  'P CHALLENGER',
#  'P CHAMBERLAIN TRIANGLE A',
#  'P CHAMBERLAIN TRIANGLE E',
#  'P CHAMBERLAIN TRIANGLE',
#  'P CHASE (SALMON) A',
#  'P CHASE (SALMON) E',
#  'P CHASE (SALMON)',
#  'P CHESTNUT A',
#  'P CHESTNUT E',
#  'P CHESTNUT',
#  "P CHICAGO WOMEN'S PARK AND GARDENS A",
#  "P CHICAGO WOMEN'S PARK AND GARDENS E",
#  "P CHICAGO WOMEN'S PARK AND GARDENS",
#  'P CHIPPEWA A',
#  'P CHIPPEWA E',
#  'P CHIPPEWA',
#  'P CHOPIN (FREDERIC) A',
#  'P CHOPIN (FREDERIC) E',
#  'P CHOPIN (FREDERIC)',
#  'P CHRISTIANA A',
#  'P CHRISTIANA E',
#  'P CHRISTIANA',
#  'P CHURCHILL FIELD A',
#  'P CHURCHILL FIELD E',
#  'P CHURCHILL FIELD',
#  'P CLAREMONT A',
#  'P CLAREMONT E',
#  'P CLAREMONT',
#  'P CLARENDON COMM. CTR. A',
#  'P CLARENDON COMM. CTR. E',
#  'P CLARENDON COMM. CTR.',
#  'P CLARK (JOHN) A',
#  'P CLARK (JOHN) E',
#  'P CLARK (JOHN)',
#  'P CLARK (RICHARD) A',
#  'P CLARK (RICHARD) E',
#  'P CLARK (RICHARD)',
#  'P CLOVER A',
#  'P CLOVER E',
#  'P CLOVER',
#  'P CLYBOURN (ARCHIBALD) A',
#  'P CLYBOURN (ARCHIBALD) E',
#  'P CLYBOURN (ARCHIBALD)',
#  'P COCHRAN (JOHN) A',
#  'P COCHRAN (JOHN) E',
#  'P COCHRAN (JOHN)',
#  'P COLE (NAT KING) A',
#  'P COLE (NAT KING) E',
#  'P COLE (NAT KING)',
#  'P COLEMAN (BESSIE) A',
#  'P COLEMAN (BESSIE) E',
#  'P COLEMAN (BESSIE)',
#  'P COLISEUM A',
#  'P COLISEUM E',
#  'P COLISEUM',
#  'P COLUMBUS (CHRISTOPHER) A',
#  'P COLUMBUS (CHRISTOPHER) E',
#  'P COLUMBUS (CHRISTOPHER)',
#  'P COMMERCIAL CLUB PGD. of CHICAGO A',
#  'P COMMERCIAL CLUB PGD. of CHICAGO E',
#  'P COMMERCIAL CLUB PGD. of CHICAGO',
#  'P CONNORS (WILLIAM) A',
#  'P CONNORS (WILLIAM) E',
#  'P CONNORS (WILLIAM)',
#  'P COOPER (JACK) A',
#  'P COOPER (JACK) E',
#  'P COOPER (JACK)',
#  'P CORNELL (PAUL) A',
#  'P CORNELL (PAUL) E',
#  'P CORNELL (PAUL)',
#  'P CORNELL (PAUL) SQUARE A',
#  'P CORNELL (PAUL) SQUARE E',
#  'P CORNELL (PAUL) SQUARE',
#  'P COSME (MARGARET) A',
#  'P COSME (MARGARET) E',
#  'P COSME (MARGARET)',
#  'P COTTON TAIL A',
#  'P COTTON TAIL E',
#  'P COTTON TAIL',
#  'P COTTONWOOD A',
#  'P COTTONWOOD E',
#  'P COTTONWOOD',
#  'P CRAGIN A',
#  'P CRAGIN E',
#  'P CRAGIN',
#  'P CRAWFORD (PETER) A',
#  'P CRAWFORD (PETER) E',
#  'P CRAWFORD (PETER)',
#  'P CRESCENT A',
#  'P CRESCENT E',
#  'P CRESCENT',
#  'P CURIE (MARIE) A',
#  'P CURIE (MARIE) E',
#  'P CURIE (MARIE)',
#  "P D'ELIA (AILEEN) A",
#  "P D'ELIA (AILEEN) E",
#  "P D'ELIA (AILEEN)",
#  'P DALEY (RICHARD J.) A',
#  'P DALEY (RICHARD J.) E',
#  'P DALEY (RICHARD J.)',
#  'P DAVIS (DR. NATHAN) SQUARE A',
#  'P DAVIS (DR. NATHAN) SQUARE E',
#  'P DAVIS (DR. NATHAN) SQUARE',
#  'P DAVIS (MARGARET) A',
#  'P DAVIS (MARGARET) E',
#  'P DAVIS (MARGARET)',
#  'P DAWES (CHARLES) A',
#  'P DAWES (CHARLES) E',
#  'P DAWES (CHARLES)',
#  'P DE BURGOS (JULIA) A',
#  'P DE BURGOS (JULIA) E',
#  'P DE BURGOS (JULIA)',
#  'P DEAN (JOHN) A',
#  'P DEAN (JOHN) E',
#  'P DEAN (JOHN)',
#  'P DEARBORN (HENRY) A',
#  'P DEARBORN (HENRY) E',
#  'P DEARBORN (HENRY)',
#  'P DEBOW (RUSSELL) A',
#  'P DEBOW (RUSSELL) E',
#  'P DEBOW (RUSSELL)',
#  'P DEGEORGE (BERNICE) A',
#  'P DEGEORGE (BERNICE) E',
#  'P DEGEORGE (BERNICE)',
#  'P DEJULIO (ANTHONY) A',
#  'P DEJULIO (ANTHONY) E',
#  'P DEJULIO (ANTHONY)',
#  'P DICKINSON (ARTHUR) A',
#  'P DICKINSON (ARTHUR) E',
#  'P DICKINSON (ARTHUR)',
#  'P DIXON (LORRAINE) A',
#  'P DIXON (LORRAINE) E',
#  'P DIXON (LORRAINE)',
#  'P DOBSON A',
#  'P DOBSON E',
#  'P DOBSON',
#  'P DOGWOOD A',
#  'P DOGWOOD E',
#  ...]

# %%
tup3 = SVD(tup2[0], tup2[1])

# %%
tup3[0].head()
# Out:
#                                          0         1         2         3  \
# (-87.930995, 41.957799)           7.452501 -2.415331  2.122308 -0.353222
# (-87.890615, 41.974689)           6.846056 -2.593422  1.839218 -0.280489
# (-87.862995, 41.992478000000006)  6.625241 -2.652850  1.583163 -0.151807
# (-87.832763, 41.944869)           5.744749 -2.252962  1.059791 -0.233730
# (-87.824812, 41.974089)           5.919241 -2.453215  1.058257 -0.087411
#
#                                              0            1            2  \
# (-87.930995, 41.957799)           15659.729641  3853.461790  3827.455257
# (-87.890615, 41.974689)           21658.491035  4478.924930  4321.933261
# (-87.862995, 41.992478000000006)  27853.259897  4836.396191  4414.361346
# (-87.832763, 41.944869)           36393.923204  6716.770461  7087.101363
# (-87.824812, 41.974089)           41503.869000  6276.862943  5880.418044
#
#                                              3
# (-87.930995, 41.957799)            4010.159684
# (-87.890615, 41.974689)            5544.188179
# (-87.862995, 41.992478000000006)   6739.771450
# (-87.832763, 41.944869)           12322.940434
# (-87.824812, 41.974089)           11648.645524

# %%
def WeatherProcess(train, test):

    def yeildWeather(target):
        weather = pd.read_csv(target)
        weather['Date'] = pd.to_datetime(weather['Date'])

        toDrop = ['Depart', 'Depth','Water1',
                'SnowFall', 'CodeSum', 'Heat',
                'Cool', 'Sunrise']
        weather = weather.drop(toDrop, axis=1)

        toReplace = {'M':np.nan, '  T': 0.001, '-': '0000'}
        for k in toReplace:
            weather = weather.replace(k, toReplace[k])


        toFloats = ['Tavg', 'WetBulb', 'PrecipTotal','StnPressure',
                    'SeaLevel', 'ResultSpeed','AvgSpeed']
        for c in toFloats:
            weather[c] = weather[c].astype(float)

        weather['Sunset'] = [date
                            if date[-2:] != '60'
                            else str(int(date[0:2])+1)+'00'
                            for date in weather['Sunset']]

        weather['Sunset'] = pd.to_datetime(weather['Sunset'],
                                            format="%H%M")
        weather.dropna(inplace=True)

        return weather[weather['Station']== 1]

    def yeildAvgTemp(weather):
        weather['Wk'] = weather['Date'].dt.week
        weekTemp = pd.DataFrame(
                        weather.groupby('Wk')['Tavg'].mean())
        weekTemp['Week'] = weekTemp.index - 17
        weekTemp['Week^2'] = weekTemp['Week']**2

        lr = LinearRegression().fit(weekTemp.drop('Tavg', axis = 'columns'),
                                    weekTemp['Tavg'])
        toRet = {}
        for w in range(1,53):
            toRet[w] = lr.intercept_ + (lr.coef_[0]*(w-17)) + (lr.coef_[1] * ((w-17)**2))

        return toRet

    def calculate_agregate( weather_sub, avgTDict):
        toRet = pd.Series()

        allAgg = [np.max, np.min, np.mean]
        toAgg = {'DewPoint': allAgg,
                'StnPressure': allAgg,
                'AvgSpeed': allAgg,
                'Tmax':[np.max],
                'Tmin':[np.min],
                'Tavg':[np.mean],
                'PrecipTotal':[np.sum, np.mean]
                }
        for k in toAgg:
            for f in toAgg[k]:
                toRet.loc[k + str(f).split(' ')[1]] = f(weather_sub[k])

        finalEntry = weather_sub.iloc[len(weather_sub)-1]

        toRet['temp_expected'] = avgTDict[pd.to_datetime(finalEntry['Date']).week]
        toRet['temp_diff'] = toRet['Tavgmean'] - toRet['temp_expected']

        sunset = finalEntry['Sunset']
        toRet['sunset'] = sunset.hour + (sunset.minute / 60)

        return toRet

    def date_ranges(dates):
        uniqueYears = set([pd.to_datetime(d).year for d in dates])

        dates = sorted(dates)
        fyear = []
        for y in uniqueYears:
            for d in dates:
                if pd.to_datetime(d).year == y:
                    fyear.append(d)
                    break

        for d in fyear:
            dates = np.insert(dates, 0, d - pd.Timedelta(days = 8))

        dateRanges = []
        for i in range(len(dates)-1):
            if pd.to_datetime(dates[i]).year == pd.to_datetime(dates[i+1]).year:
                dateRanges.append( (dates[i], dates[i+1]) )

        return dateRanges

    def subset_weather(dateRange, weather):
        mask = (weather['Date']>dateRange[0]) & (weather['Date'] <= dateRange[1])
        return weather.loc[mask]

    def TWeatherDFMaker(dct):
        toRet = pd.DataFrame().from_dict(dct)
        toRet = toRet.transpose()
        toRet.index = [idx for idx in toRet.index]
        toRet['Trap'] = toRet.index.map(lambda x: x[0])
        toRet['Date'] = toRet.index.map(lambda x: x[1])
        toRet.index = range(len(toRet))

        return toRet

    def trap_agregator(trap_df, weather, avgTDict):
        trapWeather = {}
        trap = trap_df['Trap'].iloc[0]

        dates = trap_df['Date'].unique()
        dates = sorted(dates)

        dateRanges = date_ranges(dates)

        for dr in dateRanges:
            weather_sub = subset_weather(dr, weather)
            trapWeather[(trap, dr[1])] = calculate_agregate(weather_sub, avgTDict)
        toRet = pd.DataFrame().from_dict(trapWeather)

        return TWeatherDFMaker(trapWeather)

    def transform(df):
        observations = []

        traps = df['Trap'].unique()
        for t in traps:
            observations.append(trap_agregator(df[df['Trap'] == t],
            weather, avgTDict))
        toRet = pd.concat(observations, axis = 'rows')

        return toRet

    weatherTarget = './input/weather.csv'
    weather = yeildWeather(weatherTarget)
    avgTDict = yeildAvgTemp(weather)

    return transform(train), transform(test)

# %%
tupw = WeatherProcess(tup[0],tup[1])

# %%
tupw[1].head()
# Out:
#    DewPointamax  DewPointamin  DewPointmean  StnPressureamax  StnPressureamin  \
# 0          71.0          56.0     63.750000            29.28            28.90
# 1          63.0          46.0     55.500000            29.26            29.15
# 2          54.0          46.0     51.142857            29.44            29.18
# 3          67.0          50.0     58.714286            29.28            28.98
# 4          62.0          50.0     54.333333            29.35            29.09
#
#    StnPressuremean  AvgSpeedamax  AvgSpeedamin  AvgSpeedmean  Tmaxamax  \
# 0        29.100000          21.5           5.2     11.675000      87.0
# 1        29.208333          16.3           8.8     11.200000      91.0
# 2        29.265714           7.9           5.1      6.485714      82.0
# 3        29.151429          13.2           7.3      9.214286      86.0
# 4        29.260000          13.2           6.6     10.600000      87.0
#
#    Tminamin   Tavgmean  PrecipTotalsum  PrecipTotalmean  temp_expected  \
# 0      54.0  73.125000           2.133         0.266625      70.887919
# 1      55.0  71.833333           0.570         0.095000      72.191174
# 2      52.0  68.857143           0.260         0.037143      73.228946
# 3      58.0  72.714286           0.701         0.100143      74.001234
# 4      52.0  67.333333           0.201         0.067000      74.001234
#
#    temp_diff     sunset  Trap       Date
# 0   2.237081  19.433333  T002 2008-06-11
# 1  -0.357841  19.483333  T002 2008-06-17
# 2  -4.371803  19.516667  T002 2008-06-24
# 3  -1.286948  19.516667  T002 2008-07-01
# 4  -6.667900  19.500000  T002 2008-07-04
